# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json

r = requests.get('https://api.github.com/events')

r.text

json.loads(r.text)

# 需使用json.loads()轉成json格式 不然是字串
# Out:
# [{'id': '12625083243',
#   'type': 'ForkEvent',
#   'actor': {'id': 6839831,
#    'login': 'antoniogarro',
#    'display_login': 'antoniogarro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antoniogarro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6839831?'},
#   'repo': {'id': 168213023,
#    'name': 'zwbetz-gh/cupper-hugo-theme',
#    'url': 'https://api.github.com/repos/zwbetz-gh/cupper-hugo-theme'},
#   'payload': {'forkee': {'id': 272175175,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNzIxNzUxNzU=',
#     'name': 'cupper-hugo-theme',
#     'full_name': 'antoniogarro/cupper-hugo-theme',
#     'private': False,
#     'owner': {'login': 'antoniogarro',
#      'id': 6839831,
#      'node_id': 'MDQ6VXNlcjY4Mzk4MzE=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/6839831?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/antoniogarro',
#      'html_url': 'https://github.com/antoniogarro',
#      'followers_url': 'https://api.github.com/users/antoniogarro/followers',
#      'following_url': 'https://api.github.com/users/antoniogarro/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/antoniogarro/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/antoniogarro/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/antoniogarro/subscriptions',
#      'organizations_url': 'https://api.github.com/users/antoniogarro/orgs',
#      'repos_url': 'https://api.github.com/users/antoniogarro/repos',
#      'events_url': 'https://api.github.com/users/antoniogarro/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/antoniogarro/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/antoniogarro/cupper-hugo-theme',
#     'description': 'An accessibility-friendly Hugo theme, ported from the original Cupper project.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme',
#     'forks_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/forks',
#     'keys_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/teams',
#     'hooks_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/hooks',
#     'issue_events_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/events',
#     'assignees_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/tags',
#     'blobs_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/languages',
#     'stargazers_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/stargazers',
#     'contributors_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/contributors',
#     'subscribers_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/subscribers',
#     'subscription_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/subscription',
#     'commits_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/merges',
#     'archive_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/downloads',
#     'issues_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/antoniogarro/cupper-hugo-theme/deployments',
#     'created_at': '2020-06-14T10:00:37Z',
#     'updated_at': '2020-06-13T21:20:35Z',
#     'pushed_at': '2020-06-11T18:12:57Z',
#     'git_url': 'git://github.com/antoniogarro/cupper-hugo-theme.git',
#     'ssh_url': 'git@github.com:antoniogarro/cupper-hugo-theme.git',
#     'clone_url': 'https://github.com/antoniogarro/cupper-hugo-theme.git',
#     'svn_url': 'https://github.com/antoniogarro/cupper-hugo-theme',
#     'homepage': '',
#     'size': 12256,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083242',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197736047,
#    'name': 'adeo-gitlab/sync-github-gitlab-50',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-50'},
#   'payload': {'ref': '2020-06-14_10-00-20_717_scenario2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '12625083235',
#   'type': 'PushEvent',
#   'actor': {'id': 7579238,
#    'login': 'nthiebes',
#    'display_login': 'nthiebes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nthiebes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7579238?'},
#   'repo': {'id': 68118040,
#    'name': 'nthiebes/booky.io',
#    'url': 'https://api.github.com/repos/nthiebes/booky.io'},
#   'payload': {'push_id': 5226264718,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/beta.12',
#    'head': 'd5cbea2e456974dab8aa6acc463204535260af08',
#    'before': 'c9322c3aef0f423973a6ef0963e782b84a9e40fb',
#    'commits': [{'sha': 'd5cbea2e456974dab8aa6acc463204535260af08',
#      'author': {'email': 'nico.thiebes@xing.com', 'name': 'Nico Thiebes'},
#      'message': 'update beta version',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nthiebes/booky.io/commits/d5cbea2e456974dab8aa6acc463204535260af08'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083240',
#   'type': 'PushEvent',
#   'actor': {'id': 42036176,
#    'login': 'Handsome1337',
#    'display_login': 'Handsome1337',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Handsome1337',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42036176?'},
#   'repo': {'id': 267816131,
#    'name': 'Handsome1337/react-quiz',
#    'url': 'https://api.github.com/repos/Handsome1337/react-quiz'},
#   'payload': {'push_id': 5226264721,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '23ce34003f3bb16dcbab9a20ec8ad24a9f642c58',
#    'before': 'ad160a53f61460935ca0986d607c158f041b62dc',
#    'commits': [{'sha': '44fb6e47957fed8a40d40558a8e43fc826dbae1b',
#      'author': {'email': 'volkov-ilyha@ya.ru', 'name': 'Ilya Volkov'},
#      'message': 'Настраивает приложение для внедрения Redux',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Handsome1337/react-quiz/commits/44fb6e47957fed8a40d40558a8e43fc826dbae1b'},
#     {'sha': '23ce34003f3bb16dcbab9a20ec8ad24a9f642c58',
#      'author': {'email': 'volkov-ilyha@ya.ru', 'name': 'Ilya Volkov'},
#      'message': 'Переписывает компонент QuizList на Redux',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Handsome1337/react-quiz/commits/23ce34003f3bb16dcbab9a20ec8ad24a9f642c58'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083239',
#   'type': 'WatchEvent',
#   'actor': {'id': 33365802,
#    'login': 'hassan11196',
#    'display_login': 'hassan11196',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hassan11196',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33365802?'},
#   'repo': {'id': 144863525,
#    'name': 'EthicalML/awesome-production-machine-learning',
#    'url': 'https://api.github.com/repos/EthicalML/awesome-production-machine-learning'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z',
#   'org': {'id': 43532924,
#    'login': 'EthicalML',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/EthicalML',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43532924?'}},
#  {'id': '12625083232',
#   'type': 'PushEvent',
#   'actor': {'id': 25435568,
#    'login': 'gautamajay52',
#    'display_login': 'gautamajay52',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gautamajay52',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25435568?'},
#   'repo': {'id': 271210372,
#    'name': 'gautamajay52/PublicLeech',
#    'url': 'https://api.github.com/repos/gautamajay52/PublicLeech'},
#   'payload': {'push_id': 5226264719,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b5f315f29e4fbcfed73b09cb32f9473f9c823536',
#    'before': '886e70baaca637a4578c35549dacd9f73b8ddc5c',
#    'commits': [{'sha': 'b5f315f29e4fbcfed73b09cb32f9473f9c823536',
#      'author': {'email': '25435568+gautamajay52@users.noreply.github.com',
#       'name': 'gautamajay52'},
#      'message': 'Update download_aria_p_n.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gautamajay52/PublicLeech/commits/b5f315f29e4fbcfed73b09cb32f9473f9c823536'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083231',
#   'type': 'ForkEvent',
#   'actor': {'id': 58465387,
#    'login': 'Tejaswini2403',
#    'display_login': 'Tejaswini2403',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tejaswini2403',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58465387?'},
#   'repo': {'id': 67903265,
#    'name': 'RyanFehr/HackerRank',
#    'url': 'https://api.github.com/repos/RyanFehr/HackerRank'},
#   'payload': {'forkee': {'id': 272175174,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNzIxNzUxNzQ=',
#     'name': 'HackerRank',
#     'full_name': 'Tejaswini2403/HackerRank',
#     'private': False,
#     'owner': {'login': 'Tejaswini2403',
#      'id': 58465387,
#      'node_id': 'MDQ6VXNlcjU4NDY1Mzg3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/58465387?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Tejaswini2403',
#      'html_url': 'https://github.com/Tejaswini2403',
#      'followers_url': 'https://api.github.com/users/Tejaswini2403/followers',
#      'following_url': 'https://api.github.com/users/Tejaswini2403/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Tejaswini2403/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Tejaswini2403/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Tejaswini2403/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Tejaswini2403/orgs',
#      'repos_url': 'https://api.github.com/users/Tejaswini2403/repos',
#      'events_url': 'https://api.github.com/users/Tejaswini2403/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Tejaswini2403/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Tejaswini2403/HackerRank',
#     'description': 'HackerRank solutions in Java/JS/Python/C++/C#',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Tejaswini2403/HackerRank',
#     'forks_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/forks',
#     'keys_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/teams',
#     'hooks_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/events',
#     'assignees_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/tags',
#     'blobs_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/languages',
#     'stargazers_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/subscription',
#     'commits_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/merges',
#     'archive_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/downloads',
#     'issues_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Tejaswini2403/HackerRank/deployments',
#     'created_at': '2020-06-14T10:00:36Z',
#     'updated_at': '2020-06-09T20:28:16Z',
#     'pushed_at': '2020-05-16T09:15:15Z',
#     'git_url': 'git://github.com/Tejaswini2403/HackerRank.git',
#     'ssh_url': 'git@github.com:Tejaswini2403/HackerRank.git',
#     'clone_url': 'https://github.com/Tejaswini2403/HackerRank.git',
#     'svn_url': 'https://github.com/Tejaswini2403/HackerRank',
#     'homepage': '',
#     'size': 894,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083226',
#   'type': 'CreateEvent',
#   'actor': {'id': 45942572,
#    'login': 'SiarheiSakharevich',
#    'display_login': 'SiarheiSakharevich',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SiarheiSakharevich',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45942572?'},
#   'repo': {'id': 147497474,
#    'name': 'saby/builder',
#    'url': 'https://api.github.com/repos/saby/builder'},
#   'payload': {'ref': '20.3200/mergerator/140620_130034',
#    'ref_type': 'branch',
#    'master_branch': 'rc-20.5000',
#    'description': 'Мальцев А. А. /',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z',
#   'org': {'id': 42994484,
#    'login': 'saby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/saby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42994484?'}},
#  {'id': '12625083220',
#   'type': 'CreateEvent',
#   'actor': {'id': 32801166,
#    'login': 'dymafr',
#    'display_login': 'dymafr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dymafr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32801166?'},
#   'repo': {'id': 272175172,
#    'name': 'dyma-projects/5ed8c1cb145a4919',
#    'url': 'https://api.github.com/repos/dyma-projects/5ed8c1cb145a4919'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Repo de Quentin Bregeon',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z',
#   'org': {'id': 33802621,
#    'login': 'dyma-projects',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dyma-projects',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33802621?'}},
#  {'id': '12625083218',
#   'type': 'PushEvent',
#   'actor': {'id': 33175115,
#    'login': '5uga',
#    'display_login': '5uga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/5uga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33175115?'},
#   'repo': {'id': 197016542,
#    'name': '5uga/5uga.github.io',
#    'url': 'https://api.github.com/repos/5uga/5uga.github.io'},
#   'payload': {'push_id': 5226264714,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bab306281be43c748fa774d3861184365a60afa3',
#    'before': 'ce3c218048fb5e35b58926a0e496ca6c6bf29a83',
#    'commits': [{'sha': 'bab306281be43c748fa774d3861184365a60afa3',
#      'author': {'email': 'c0swangyi@163.com', 'name': '5uga'},
#      'message': 'Site updated: 2020-06-14 17:59:59',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/5uga/5uga.github.io/commits/bab306281be43c748fa774d3861184365a60afa3'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083217',
#   'type': 'ForkEvent',
#   'actor': {'id': 64013941,
#    'login': 'Project-Elice',
#    'display_login': 'Project-Elice',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Project-Elice',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64013941?'},
#   'repo': {'id': 37448451,
#    'name': 'mattermost/mattermost-server',
#    'url': 'https://api.github.com/repos/mattermost/mattermost-server'},
#   'payload': {'forkee': {'id': 272175171,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNzIxNzUxNzE=',
#     'name': 'mattermost-server',
#     'full_name': 'Project-Elice/mattermost-server',
#     'private': False,
#     'owner': {'login': 'Project-Elice',
#      'id': 64013941,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY0MDEzOTQx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/64013941?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Project-Elice',
#      'html_url': 'https://github.com/Project-Elice',
#      'followers_url': 'https://api.github.com/users/Project-Elice/followers',
#      'following_url': 'https://api.github.com/users/Project-Elice/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Project-Elice/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Project-Elice/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Project-Elice/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Project-Elice/orgs',
#      'repos_url': 'https://api.github.com/users/Project-Elice/repos',
#      'events_url': 'https://api.github.com/users/Project-Elice/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Project-Elice/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/Project-Elice/mattermost-server',
#     'description': 'Open source Slack-alternative in Golang and React - Mattermost',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Project-Elice/mattermost-server',
#     'forks_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/forks',
#     'keys_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/teams',
#     'hooks_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/events',
#     'assignees_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/tags',
#     'blobs_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/languages',
#     'stargazers_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/subscription',
#     'commits_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/merges',
#     'archive_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/downloads',
#     'issues_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Project-Elice/mattermost-server/deployments',
#     'created_at': '2020-06-14T10:00:36Z',
#     'updated_at': '2020-06-14T08:37:51Z',
#     'pushed_at': '2020-06-14T08:31:22Z',
#     'git_url': 'git://github.com/Project-Elice/mattermost-server.git',
#     'ssh_url': 'git@github.com:Project-Elice/mattermost-server.git',
#     'clone_url': 'https://github.com/Project-Elice/mattermost-server.git',
#     'svn_url': 'https://github.com/Project-Elice/mattermost-server',
#     'homepage': 'https://mattermost.com',
#     'size': 386484,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'other',
#      'name': 'Other',
#      'spdx_id': 'NOASSERTION',
#      'url': None,
#      'node_id': 'MDc6TGljZW5zZTA='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z',
#   'org': {'id': 9828093,
#    'login': 'mattermost',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mattermost',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9828093?'}},
#  {'id': '12625083215',
#   'type': 'CreateEvent',
#   'actor': {'id': 1553,
#    'login': 'Jonty',
#    'display_login': 'Jonty',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jonty',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1553?'},
#   'repo': {'id': 263878630,
#    'name': 'alphagov-mirror/paas-product-pages',
#    'url': 'https://api.github.com/repos/alphagov-mirror/paas-product-pages'},
#   'payload': {'ref': 'revert-bundle-govuk-frontend-javascript',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z',
#   'org': {'id': 54668267,
#    'login': 'alphagov-mirror',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alphagov-mirror',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54668267?'}},
#  {'id': '12625083214',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 167670101,
#    'name': 'alexandruspataru/nx-starter',
#    'url': 'https://api.github.com/repos/alexandruspataru/nx-starter'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/alexandruspataru/nx-starter/issues/4',
#     'repository_url': 'https://api.github.com/repos/alexandruspataru/nx-starter',
#     'labels_url': 'https://api.github.com/repos/alexandruspataru/nx-starter/issues/4/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/alexandruspataru/nx-starter/issues/4/comments',
#     'events_url': 'https://api.github.com/repos/alexandruspataru/nx-starter/issues/4/events',
#     'html_url': 'https://github.com/alexandruspataru/nx-starter/pull/4',
#     'id': 632591431,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDI5MzE3MDU2',
#     'number': 4,
#     'title': 'Bump websocket-extensions from 0.1.3 to 0.1.4 in /assets',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1719809561,
#       'node_id': 'MDU6TGFiZWwxNzE5ODA5NTYx',
#       'url': 'https://api.github.com/repos/alexandruspataru/nx-starter/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-06-06T17:00:53Z',
#     'updated_at': '2020-06-14T10:00:36Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/alexandruspataru/nx-starter/pulls/4',
#      'html_url': 'https://github.com/alexandruspataru/nx-starter/pull/4',
#      'diff_url': 'https://github.com/alexandruspataru/nx-starter/pull/4.diff',
#      'patch_url': 'https://github.com/alexandruspataru/nx-starter/pull/4.patch'},
#     'body': '[//]: # (dependabot-start)\n⚠️  **Dependabot is rebasing this PR** ⚠️ \n\nIf you make any changes to it yourself then they will take precedence over the rebase.\n\n---\n\n[//]: # (dependabot-end)\n\nBumps [websocket-extensions](https://github.com/faye/websocket-extensions-node) from 0.1.3 to 0.1.4.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/faye/websocket-extensions-node/blob/master/CHANGELOG.md">websocket-extensions\'s changelog</a>.</em></p>\n<blockquote>\n<h3>0.1.4 / 2020-06-02</h3>\n<ul>\n<li>Remove a ReDoS vulnerability in the header parser (CVE-2020-7662, reported by\nRobert McLaughlin)</li>\n<li>Change license from MIT to Apache 2.0</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/8efd0cd6e35faf9bb9cb08759be1e27082177d43"><code>8efd0cd</code></a> Bump version to 0.1.4</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/3dad4ad44a8c5f74d4f8f4efd3f9d6e0b5df3051"><code>3dad4ad</code></a> Remove ReDoS vulnerability in the Sec-WebSocket-Extensions header parser</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/4a76c75efb1c5d6a2f60550e9501757458d19533"><code>4a76c75</code></a> Add Node versions 13 and 14 on Travis</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/44a677a9c0631daed0b0f4a4b68c095b624183b8"><code>44a677a</code></a> Formatting change: {...} should have spaces inside the braces</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/f6c50aba0c20ff45b0f87cea33babec1217ec3f5"><code>f6c50ab</code></a> Let npm reformat package.json</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/2d211f3705d52d9efb4f01daf5a253adf828592e"><code>2d211f3</code></a> Change markdown formatting of docs.</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/0b620834cc1e1f2eace1d55ab17f71d90d88271d"><code>0b62083</code></a> Update Travis target versions.</li>\n<li><a href="https://github.com/faye/websocket-extensions-node/commit/729a4653073fa8dd020561113513bfa2e2119415"><code>729a465</code></a> Switch license to Apache 2.0.</li>\n<li>See full diff in <a href="https://github.com/faye/websocket-extensions-node/compare/0.1.3...0.1.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=websocket-extensions&package-manager=npm_and_yarn&previous-version=0.1.3&new-version=0.1.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR o ...
#    'comment': {'url': 'https://api.github.com/repos/alexandruspataru/nx-starter/issues/comments/643744715',
#     'html_url': 'https://github.com/alexandruspataru/nx-starter/pull/4#issuecomment-643744715',
#     'issue_url': 'https://api.github.com/repos/alexandruspataru/nx-starter/issues/4',
#     'id': 643744715,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY0Mzc0NDcxNQ==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-06-14T10:00:36Z',
#     'updated_at': '2020-06-14T10:00:36Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Looks like websocket-extensions is no longer a dependency, so this is no longer needed.'}},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083213',
#   'type': 'PushEvent',
#   'actor': {'id': 19212469,
#    'login': 'harisyammnv',
#    'display_login': 'harisyammnv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harisyammnv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19212469?'},
#   'repo': {'id': 264489840,
#    'name': 'harisyammnv/DEND_Capstone_Airflow_EMR',
#    'url': 'https://api.github.com/repos/harisyammnv/DEND_Capstone_Airflow_EMR'},
#   'payload': {'push_id': 5226264710,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2ab8fac015eadbbe202e17798739ff53c2744ff6',
#    'before': 'ba3c5cc58fe3643a7f76449f3744ca7939791348',
#    'commits': [{'sha': '2ab8fac015eadbbe202e17798739ff53c2744ff6',
#      'author': {'email': 'harisyam.bphc@gmail.com', 'name': 'harisyammnv'},
#      'message': 'DWH updated with queries',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/harisyammnv/DEND_Capstone_Airflow_EMR/commits/2ab8fac015eadbbe202e17798739ff53c2744ff6'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:37Z'},
#  {'id': '12625083206',
#   'type': 'CreateEvent',
#   'actor': {'id': 63811129,
#    'login': 'luizfernandohenriques',
#    'display_login': 'luizfernandohenriques',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luizfernandohenriques',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63811129?'},
#   'repo': {'id': 265692708,
#    'name': 'luizfernandohenriques/libpythonpro2',
#    'url': 'https://api.github.com/repos/luizfernandohenriques/libpythonpro2'},
#   'payload': {'ref': 'pyup-update-certifi-2020.4.5.1-to-2020.4.5.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083203',
#   'type': 'PushEvent',
#   'actor': {'id': 16347475,
#    'login': 'laksa19',
#    'display_login': 'laksa19',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/laksa19',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16347475?'},
#   'repo': {'id': 258700432,
#    'name': 'laksa19/laksa19.github.io',
#    'url': 'https://api.github.com/repos/laksa19/laksa19.github.io'},
#   'payload': {'push_id': 5226264703,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '44e1663c4b6f3994ea7a324ae17153d39d3740c6',
#    'before': '52298a38dce3722e10175343c4807dcb7c79f863',
#    'commits': [{'sha': '44e1663c4b6f3994ea7a324ae17153d39d3740c6',
#      'author': {'email': 'elru.lakusa@gmail.com', 'name': 'Laksamadi Guko'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/laksa19/laksa19.github.io/commits/44e1663c4b6f3994ea7a324ae17153d39d3740c6'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083196',
#   'type': 'PushEvent',
#   'actor': {'id': 61094433,
#    'login': 'D3VSJ',
#    'display_login': 'D3VSJ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/D3VSJ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61094433?'},
#   'repo': {'id': 254170203,
#    'name': 'D3VSJ/xBrowser',
#    'url': 'https://api.github.com/repos/D3VSJ/xBrowser'},
#   'payload': {'push_id': 5226264702,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0af9d30981a7c7cc1c43e36357e990bbe546cd54',
#    'before': 'b21418e992c6d2ca64ebcad3dca3be0d532e9f6f',
#    'commits': [{'sha': '0af9d30981a7c7cc1c43e36357e990bbe546cd54',
#      'author': {'email': 'sunilsanjay2006@outlook.com', 'name': 'D3VSJ'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/D3VSJ/xBrowser/commits/0af9d30981a7c7cc1c43e36357e990bbe546cd54'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083201',
#   'type': 'CreateEvent',
#   'actor': {'id': 66885124,
#    'login': 'ShapeGen',
#    'display_login': 'ShapeGen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShapeGen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66885124?'},
#   'repo': {'id': 272175169,
#    'name': 'ShapeGen/Holistic_Generation',
#    'url': 'https://api.github.com/repos/ShapeGen/Holistic_Generation'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083200',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 272173466,
#    'name': 'wonlon/vue_admin',
#    'url': 'https://api.github.com/repos/wonlon/vue_admin'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/wonlon/vue_admin/pulls/2',
#     'id': 434121768,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM0MTIxNzY4',
#     'html_url': 'https://github.com/wonlon/vue_admin/pull/2',
#     'diff_url': 'https://github.com/wonlon/vue_admin/pull/2.diff',
#     'patch_url': 'https://github.com/wonlon/vue_admin/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/wonlon/vue_admin/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump webpack-dev-server from 2.11.5 to 3.1.11',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
# ...
#    'url': 'https://api.github.com/users/himobi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40586421?'},
#   'repo': {'id': 138676186,
#    'name': 'himobi/hotspot',
#    'url': 'https://api.github.com/repos/himobi/hotspot'},
#   'payload': {'push_id': 5226264696,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'eb78dd2974ef7e29fe5267c89a99f39a184dc594',
#    'before': '0f78e22f18e2cbfc036d96f15c3ba78f4957ff4d',
#    'commits': [{'sha': 'eb78dd2974ef7e29fe5267c89a99f39a184dc594',
#      'author': {'email': '40586421+himobi@users.noreply.github.com',
#       'name': 'himobi'},
#      'message': 'thank you',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/himobi/hotspot/commits/eb78dd2974ef7e29fe5267c89a99f39a184dc594'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083195',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 24364012,
#    'login': 'eankeen',
#    'display_login': 'eankeen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eankeen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24364012?'},
#   'repo': {'id': 262316588,
#    'name': 'eankeen/fox-suite',
#    'url': 'https://api.github.com/repos/eankeen/fox-suite'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/eankeen/fox-suite/issues/66',
#     'repository_url': 'https://api.github.com/repos/eankeen/fox-suite',
#     'labels_url': 'https://api.github.com/repos/eankeen/fox-suite/issues/66/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/eankeen/fox-suite/issues/66/comments',
#     'events_url': 'https://api.github.com/repos/eankeen/fox-suite/issues/66/events',
#     'html_url': 'https://github.com/eankeen/fox-suite/issues/66',
#     'id': 638280475,
#     'node_id': 'MDU6SXNzdWU2MzgyODA0NzU=',
#     'number': 66,
#     'title': 'Can not find default.json',
#     'user': {'login': 'hkatzdev',
#      'id': 44281159,
#      'node_id': 'MDQ6VXNlcjQ0MjgxMTU5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/44281159?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hkatzdev',
#      'html_url': 'https://github.com/hkatzdev',
#      'followers_url': 'https://api.github.com/users/hkatzdev/followers',
#      'following_url': 'https://api.github.com/users/hkatzdev/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hkatzdev/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hkatzdev/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hkatzdev/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hkatzdev/orgs',
#      'repos_url': 'https://api.github.com/users/hkatzdev/repos',
#      'events_url': 'https://api.github.com/users/hkatzdev/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hkatzdev/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2046070848,
#       'node_id': 'MDU6TGFiZWwyMDQ2MDcwODQ4',
#       'url': 'https://api.github.com/repos/eankeen/fox-suite/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'eankeen',
#      'id': 24364012,
#      'node_id': 'MDQ6VXNlcjI0MzY0MDEy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/24364012?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eankeen',
#      'html_url': 'https://github.com/eankeen',
#      'followers_url': 'https://api.github.com/users/eankeen/followers',
#      'following_url': 'https://api.github.com/users/eankeen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eankeen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eankeen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eankeen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eankeen/orgs',
#      'repos_url': 'https://api.github.com/users/eankeen/repos',
#      'events_url': 'https://api.github.com/users/eankeen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eankeen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'eankeen',
#       'id': 24364012,
#       'node_id': 'MDQ6VXNlcjI0MzY0MDEy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/24364012?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/eankeen',
#       'html_url': 'https://github.com/eankeen',
#       'followers_url': 'https://api.github.com/users/eankeen/followers',
#       'following_url': 'https://api.github.com/users/eankeen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/eankeen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/eankeen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/eankeen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/eankeen/orgs',
#       'repos_url': 'https://api.github.com/users/eankeen/repos',
#       'events_url': 'https://api.github.com/users/eankeen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/eankeen/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/eankeen/fox-suite/milestones/2',
#      'html_url': 'https://github.com/eankeen/fox-suite/milestone/2',
#      'labels_url': 'https://api.github.com/repos/eankeen/fox-suite/milestones/2/labels',
#      'id': 5502304,
#      'node_id': 'MDk6TWlsZXN0b25lNTUwMjMwNA==',
#      'number': 2,
#      'title': '1.1.0',
#      'description': '',
#      'creator': {'login': 'eankeen',
#       'id': 24364012,
#       'node_id': 'MDQ6VXNlcjI0MzY0MDEy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/24364012?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/eankeen',
#       'html_url': 'https://github.com/eankeen',
#       'followers_url': 'https://api.github.com/users/eankeen/followers',
#       'following_url': 'https://api.github.com/users/eankeen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/eankeen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/eankeen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/eankeen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/eankeen/orgs',
#       'repos_url': 'https://api.github.com/users/eankeen/repos',
#       'events_url': 'https://api.github.com/users/eankeen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/eankeen/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 4,
#      'closed_issues': 5,
#      'state': 'open',
#      'created_at': '2020-06-05T03:31:39Z',
#      'updated_at': '2020-06-14T09:59:05Z',
#      'due_on': '2020-06-08T07:00:00Z',
#      'closed_at': None},
#     'comments': 1,
#     'created_at': '2020-06-14T04:19:52Z',
#     'updated_at': '2020-06-14T10:00:36Z',
#     'closed_at': '2020-06-14T09:59:04Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': "`[Error: ENOENT: no such file or directory, open '/home/hkatzdev/hackagotchi-automator/node_modules/.pnpm/fox-utils@1.0.1/node_modules/fox-utils/src/default.json'] {\r\n  errno: -2,\r\n  code: 'ENOENT',\r\n  syscall: 'open',\r\n  path: '/home/hkatzdev/hackagotchi-automator/node_modules/.pnpm/fox-utils@1.0.1/node_modules/fox-utils/src/default.json'\r\n}\r\n`"},
#    'comment': {'url': 'https://api.github.com/repos/eankeen/fox-suite/issues/comments/643744713',
#     'html_url': 'https://github.com/eankeen/fox-suite/issues/66#issuecomment-643744713',
#     'issue_url': 'https://api.github.com/repos/eankeen/fox-suite/issues/66',
#     'id': 643744713,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY0Mzc0NDcxMw==',
#     'user': {'login': 'eankeen',
#      'id': 24364012,
#      'node_id': 'MDQ6VXNlcjI0MzY0MDEy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/24364012?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eankeen',
#      'html_url': 'https://github.com/eankeen',
#      'followers_url': 'https://api.github.com/users/eankeen/followers',
#      'following_url': 'https://api.github.com/users/eankeen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eankeen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eankeen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eankeen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eankeen/orgs',
#      'repos_url': 'https://api.github.com/users/eankeen/repos',
#      'events_url': 'https://api.github.com/users/eankeen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eankeen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-06-14T10:00:36Z',
#     'updated_at': '2020-06-14T10:00:36Z',
#     'author_association': 'OWNER',
#     'body': "hai,\r\n\r\nthis was fixed in `1.0.4` :)\r\ni'm' still working on getting a few bugs and in consistencies out - i admit the `1.0.0` version designation may have been a tad premature"}},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083189',
#   'type': 'PushEvent',
#   'actor': {'id': 5324707,
#    'login': 'parsley42',
#    'display_login': 'parsley42',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/parsley42',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5324707?'},
#   'repo': {'id': 162754315,
#    'name': 'parsley42/clu-gopherbot',
#    'url': 'https://api.github.com/repos/parsley42/clu-gopherbot'},
#   'payload': {'push_id': 5226264695,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/robot-state',
#    'head': 'dfabcd4e7c1123ede4246aa92d297c0a064f9d26',
#    'before': 'bc58ebf84b1ebbcea5adb7c2503783c6aacb8726',
#    'commits': [{'sha': 'dfabcd4e7c1123ede4246aa92d297c0a064f9d26',
#      'author': {'email': 'clu@linuxjedi.org', 'name': 'Clu Gopherbot'},
#      'message': 'Automated backup of robot state',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/parsley42/clu-gopherbot/commits/dfabcd4e7c1123ede4246aa92d297c0a064f9d26'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083190',
#   'type': 'PushEvent',
#   'actor': {'id': 1511506,
#    'login': 'cain19811028',
#    'display_login': 'cain19811028',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cain19811028',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1511506?'},
#   'repo': {'id': 114507337,
#    'name': 'cain19811028/python_notebook',
#    'url': 'https://api.github.com/repos/cain19811028/python_notebook'},
#   'payload': {'push_id': 5226264697,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '30c004969c1c522045250f8d221ff3271cbb6def',
#    'before': '30794ba119635b4b1830dd42051a39cf227cfea4',
#    'commits': [{'sha': '30c004969c1c522045250f8d221ff3271cbb6def',
#      'author': {'email': 'cain19811028@gmail.com', 'name': 'Cain HC Chen'},
#      'message': 'update framework.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cain19811028/python_notebook/commits/30c004969c1c522045250f8d221ff3271cbb6def'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083188',
#   'type': 'PushEvent',
#   'actor': {'id': 65212910,
#    'login': 'Hall-1910',
#    'display_login': 'Hall-1910',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hall-1910',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65212910?'},
#   'repo': {'id': 222505696,
#    'name': 'brand22/d3',
#    'url': 'https://api.github.com/repos/brand22/d3'},
#   'payload': {'push_id': 5226264693,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2531b53c61cc8a8e316731c1e1cf7b02b89eed51',
#    'before': '3890ef1229bb651077ea3ce69855890576954add',
#    'commits': [{'sha': '2531b53c61cc8a8e316731c1e1cf7b02b89eed51',
#      'author': {'email': '65212910+Hall-1910@users.noreply.github.com',
#       'name': 'Hall-1910'},
#      'message': 'm',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brand22/d3/commits/2531b53c61cc8a8e316731c1e1cf7b02b89eed51'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083192',
#   'type': 'CreateEvent',
#   'actor': {'id': 36897971,
#    'login': 'anastasiia-kryshtop',
#    'display_login': 'anastasiia-kryshtop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anastasiia-kryshtop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36897971?'},
#   'repo': {'id': 27916574,
#    'name': 'vcsbroker/test-dev',
#    'url': 'https://api.github.com/repos/vcsbroker/test-dev'},
#   'payload': {'ref': 'test-head',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'repo-connector dev testing repository',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083187',
#   'type': 'WatchEvent',
#   'actor': {'id': 8406903,
#    'login': 'faizankshaikh',
#    'display_login': 'faizankshaikh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/faizankshaikh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8406903?'},
#   'repo': {'id': 104394093,
#    'name': 'nikitavoloboev/knowledge',
#    'url': 'https://api.github.com/repos/nikitavoloboev/knowledge'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083182',
#   'type': 'PushEvent',
#   'actor': {'id': 879532,
#    'login': 'PhilipSkinner',
#    'display_login': 'PhilipSkinner',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PhilipSkinner',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/879532?'},
#   'repo': {'id': 234766886,
#    'name': 'PhilipSkinner/elemental-lowcode',
#    'url': 'https://api.github.com/repos/PhilipSkinner/elemental-lowcode'},
#   'payload': {'push_id': 5226264688,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd9c19f9c54776ae3f07b02d19bb1c30d3829acae',
#    'before': 'ffabe7399fe593ca3a2249e7d0be031dd97c3a6f',
#    'commits': [{'sha': 'd9c19f9c54776ae3f07b02d19bb1c30d3829acae',
#      'author': {'email': 'me@philip-skinner.co.uk', 'name': 'Philip Skinner'},
#      'message': '[+] Adds definitions for data structure\n[+] Replaces db implementation with one that backs onto the storage\nengines used within the data API.\n[*] Adds better top bar navigation on admin.\n[+] Adds ability to configure security storage settings via admin.\n[*] Tweaks to documentation look/feel\n[*] Makes alerts more visible\n[+] Adds idp documentation\n[*] Corrects bugs found within sql storage engine - race conditions\non the system not being ready etc.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PhilipSkinner/elemental-lowcode/commits/d9c19f9c54776ae3f07b02d19bb1c30d3829acae'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'},
#  {'id': '12625083178',
#   'type': 'PushEvent',
#   'actor': {'id': 65212910,
#    'login': 'Hall-1910',
#    'display_login': 'Hall-1910',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hall-1910',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65212910?'},
#   'repo': {'id': 222505696,
#    'name': 'brand22/d3',
#    'url': 'https://api.github.com/repos/brand22/d3'},
#   'payload': {'push_id': 5226264686,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'db8e9f3fd313b2e566b156f901841fdd22ede01c',
#    'before': '9f50582025ebf91d0a853396f07b0bae74105eb7',
#    'commits': [{'sha': 'db8e9f3fd313b2e566b156f901841fdd22ede01c',
#      'author': {'email': '65212910+Hall-1910@users.noreply.github.com',
#       'name': 'Hall-1910'},
#      'message': 'm',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brand22/d3/commits/db8e9f3fd313b2e566b156f901841fdd22ede01c'}]},
#   'public': True,
#   'created_at': '2020-06-14T10:00:36Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
# 新冠狀病毒API
covid19Data= requests.get('https://api.covid19api.com/summary')

json.loads(covid19Data.text)
# Out:
# {'Global': {'NewConfirmed': 134598,
#   'TotalConfirmed': 7866274,
#   'NewDeaths': 4401,
#   'TotalDeaths': 437903,
#   'NewRecovered': 85027,
#   'TotalRecovered': 3697653},
#  'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 556,
#    'TotalConfirmed': 24102,
#    'NewDeaths': 5,
#    'TotalDeaths': 451,
#    'NewRecovered': 273,
#    'TotalRecovered': 4201,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 1464,
#    'NewDeaths': 0,
#    'TotalDeaths': 36,
#    'NewRecovered': 5,
#    'TotalRecovered': 1039,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 112,
#    'TotalConfirmed': 10810,
#    'NewDeaths': 9,
#    'TotalDeaths': 760,
#    'NewRecovered': 98,
#    'TotalRecovered': 7420,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 853,
#    'NewDeaths': 0,
#    'TotalDeaths': 51,
#    'NewRecovered': 0,
#    'TotalRecovered': 781,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 138,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 19,
#    'TotalRecovered': 61,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 20,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 1531,
#    'TotalConfirmed': 30295,
#    'NewDeaths': 30,
#    'TotalDeaths': 815,
#    'NewRecovered': 340,
#    'TotalRecovered': 9083,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 723,
#    'TotalConfirmed': 16004,
#    'NewDeaths': 6,
#    'TotalDeaths': 264,
#    'NewRecovered': 442,
#    'TotalRecovered': 6081,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 7320,
#    'NewDeaths': 0,
#    'TotalDeaths': 102,
#    'NewRecovered': 35,
#    'TotalRecovered': 6838,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 17078,
#    'NewDeaths': 2,
#    'TotalDeaths': 677,
#    'NewRecovered': 27,
#    'TotalRecovered': 16012,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 352,
#    'TotalConfirmed': 9570,
#    'NewDeaths': 2,
#    'TotalDeaths': 115,
#    'NewRecovered': 193,
#    'TotalRecovered': 5309,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103,
#    'NewDeaths': 0,
#    'TotalDeaths': 11,
#    'NewRecovered': 0,
#    'TotalRecovered': 68,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 444,
#    'TotalConfirmed': 17713,
#    'NewDeaths': 1,
#    'TotalDeaths': 37,
#    'NewRecovered': 288,
#    'TotalRecovered': 12191,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 2856,
#    'TotalConfirmed': 84379,
#    'NewDeaths': 44,
#    'TotalDeaths': 1139,
#    'NewRecovered': 579,
#    'TotalRecovered': 17828,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 96,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 83,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 721,
#    'TotalConfirmed': 53241,
#    'NewDeaths': 5,
#    'TotalDeaths': 303,
#    'NewRecovered': 1351,
#    'TotalRecovered': 29111,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 99,
#    'TotalConfirmed': 59918,
#    'NewDeaths': 4,
#    'TotalDeaths': 9650,
#    'NewRecovered': 49,
#    'TotalRecovered': 16547,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 16,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 412,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 5,
#    'TotalRecovered': 222,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 66,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 21,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 913,
#    'TotalConfirmed': 17842,
#    'NewDeaths': 26,
#    'TotalDeaths': 585,
#    'NewRecovered': 337,
#    'TotalRecovered': 2768,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2893,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 2119,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 60,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 24,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 21704,
#    'TotalConfirmed': 850514,
#    'NewDeaths': 892,
#    'TotalDeaths': 42720,
#    'NewRecovered': 14313,
#    'TotalRecovered': 459436,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 141,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 138,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 75,
#    'TotalConfirmed': 3266,
#    'NewDeaths': 0,
#    'TotalDeaths': 172,
#    'NewRecovered': 7,
#    'TotalRecovered': 1723,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 892,
#    'NewDeaths': 0,
#    'TotalDeaths': 53,
#    'NewRecovered': 8,
#    'TotalRecovered': 799,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 85,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 45,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 128,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 125,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8681,
#    'NewDeaths': 0,
#    'TotalDeaths': 212,
#    'NewRecovered': 0,
#    'TotalRecovered': 4836,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 896,
#    'TotalConfirmed': 200086,
#    'NewDeaths': 116,
#    'TotalDeaths': 16364,
#    'NewRecovered': 817,
#    'TotalRecovered': 59851,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 726,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 294,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 2057,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 3,
#    'TotalRecovered': 363,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 848,
#    'NewDeaths': 0,
#    'TotalDeaths': 72,
#    'NewRecovered': 7,
#    'TotalRecovered': 718,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 6509,
#    'TotalConfirmed': 167355,
#    'NewDeaths': 231,
#    'TotalDeaths': 3101,
#    'NewRecovered': 5938,
#    'TotalRecovered': 137296,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 58,
#    'TotalConfirmed': 84286,
#    'NewDeaths': 0,
#    'TotalDeaths': 4638,
#    'NewRecovered': 3,
#    'TotalRecovered': 79475,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 1650,
#    'TotalConfirmed': 46994,
#    'NewDeaths': 61,
#    'TotalDeaths': 1623,
#    'NewRecovered': 926,
#    'TotalRecovered': 18749,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 176,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 17,
#    'TotalRecovered': 114,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 728,
#    'NewDeaths': 0,
#    'TotalDeaths': 24,
#    'NewRecovered': 0,
#    'TotalRecovered': 221,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 87,
#    'TotalConfirmed': 4724,
#    'NewDeaths': 5,
#    'TotalDeaths': 106,
#    'NewRecovered': 15,
#    'TotalRecovered': 595,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 1662,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 12,
#    'TotalRecovered': 743,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 2251,
#    'NewDeaths': 0,
#    'TotalDeaths': 107,
#    'NewRecovered': 1,
#    'TotalRecovered': 2134,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 2238,
#    'NewDeaths': 0,
#    'TotalDeaths': 84,
#    'NewRecovered': 21,
#    'TotalRecovered': 1923,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 980,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 0,
#    'TotalRecovered': 807,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 53,
#    'TotalConfirmed': 9991,
#    'NewDeaths': 0,
#    'TotalDeaths': 329,
#    'NewRecovered': 4,
#    'TotalRecovered': 7219,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 164,
#    'TotalConfirmed': 4848,
#    'NewDeaths': 0,
#    'TotalDeaths': 45,
#    'NewRecovered': 134,
#    'TotalRecovered': 2397,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 40,
#    'TotalConfirmed': 12339,
#    'NewDeaths': 3,
#    'TotalDeaths': 597,
#    'NewRecovered': 42,
#    'TotalRecovered': 11235,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 4449,
#    'NewDeaths': 3,
#    'TotalDeaths': 41,
#    'NewRecovered': 93,
#    'TotalRecovered': 2823,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 16,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 564,
#    'TotalConfirmed': 22572,
#    'NewDeaths': 9,
#    'TotalDeaths': 577,
#    'NewRecovered': 330,
#    'TotalRecovered': 13084,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 578,
#    'TotalConfirmed': 46356,
#    'NewDeaths': 46,
#    'TotalDeaths': 3874,
#    'NewRecovered': 186,
#    'TotalRecovered': 22865,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 1677,
#    'TotalConfirmed': 42980,
#    'NewDeaths': 62,
#    'TotalDeaths': 1484,
#    'NewRecovered': 421,
#    'TotalRecovered': 11529,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 122,
#    'TotalConfirmed': 3603,
#    'NewDeaths': 4,
#    'TotalDeaths': 72,
#    'NewRecovered': 151,
#    'TotalRecovered': 1738,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1306,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 200,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 65,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 39,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 1973,
#    'NewDeaths': 0,
#    'TotalDeaths': 69,
#    'NewRecovered': 2,
#    'TotalRecovered': 1705,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 251,
#    'TotalConfirmed': 3166,
#    'NewDeaths': 8,
#    'TotalDeaths': 55,
#    'NewRecovered': 44,
#    'TotalRecovered': 495,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 18,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 7087,
#    'NewDeaths': 0,
#    'TotalDeaths': 325,
#    'NewRecovered': 0,
#    'TotalRecovered': 6200,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 526,
#    'TotalConfirmed': 193746,
#    'NewDeaths': 24,
#    'TotalDeaths': 29401,
#    'NewRecovered': 236,
#    'TotalRecovered': 72931,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3463,
#    'NewDeaths': 0,
#    'TotalDeaths': 23,
#    'NewRecovered': 0,
#    'TotalRecovered': 1024,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 28,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 2,
#    'TotalRecovered': 24,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 851,
#    'NewDeaths': 1,
#    'TotalDeaths': 14,
#    'NewRecovered': 5,
#    'TotalRecovered': 702,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 187267,
#    'NewDeaths': 10,
#    'TotalDeaths': 8793,
#    'NewRecovered': 435,
#    'TotalRecovered': 171970,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 262,
#    'TotalConfirmed': 11118,
#    'NewDeaths': 0,
#    'TotalDeaths': 48,
#    'NewRecovered': 58,
#    'TotalRecovered': 3979,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 3112,
#    'NewDeaths': 0,
#    'TotalDeaths': 183,
#    'NewRecovered': 0,
#    'TotalRecovered': 1374,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 22,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 509,
#    'TotalConfirmed': 9491,
#    'NewDeaths': 16,
#    'TotalDeaths': 367,
#    'NewRecovered': 102,
#    'TotalRecovered': 1804,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 58,
#    'TotalConfirmed': 4484,
#    'NewDeaths': 1,
#    'TotalDeaths': 25,
#    'NewRecovered': 107,
#    'TotalRecovered': 3213,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1460,
#    'NewDeaths': 0,
#    'TotalDeaths': 15,
#    'NewRecovered': 0,
#    'TotalRecovered': 153,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 159,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 95,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 224,
#    'TotalConfirmed': 4165,
#    'NewDeaths': 6,
#    'TotalDeaths': 70,
#    'NewRecovered': 0,
#    'TotalRecovered': 24,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 12,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 323,
#    'TotalConfirmed': 8455,
#    'NewDeaths': 4,
#    'TotalDeaths': 310,
#    'NewRecovered': 50,
#    'TotalRecovered': 894,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 4064,
#    'NewDeaths': 4,
#    'TotalDeaths': 559,
#    'NewRecovered': 29,
#    'TotalRecovered': 2476,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1808,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 1794,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 11458,
#    'TotalConfirmed': 308993,
#    'NewDeaths': 386,
#    'TotalDeaths': 8884,
#    'NewRecovered': 7135,
#    'TotalRecovered': 154330,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 1014,
#    'TotalConfirmed': 37420,
#    'NewDeaths': 43,
#    'TotalDeaths': 2091,
#    'NewRecovered': 563,
#    'TotalRecovered': 13776,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 2430,
#    'TotalConfirmed': 184955,
#    'NewDeaths': 71,
#    'TotalDeaths': 8730,
#    'NewRecovered': 2099,
#    'TotalRecovered': 146748,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 1180,
#    'TotalConfirmed': 18950,
#    'NewDeaths': 53,
#    'TotalDeaths': 549,
#    'NewRecovered': 647,
#    'TotalRecovered': 7515,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 45,
#    'TotalConfirmed': 25295,
#    'NewDeaths': 0,
#    'TotalDeaths': 1705,
#    'NewRecovered': 0,
#    'TotalRecovered': 22698,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 177,
#    'TotalConfirmed': 18972,
#    'NewDeaths': 0,
#    'TotalDeaths': 300,
#    'NewRecovered': 69,
#    'TotalRecovered': 15357,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 346,
#    'TotalConfirmed': 236651,
#    'NewDeaths': 78,
#    'TotalDeaths': 34301,
#    'NewRecovered': 1780,
#    'TotalRecovered': 174865,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 615,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 3,
#    'TotalRecovered': 420,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 43,
#    'TotalConfirmed': 17293,
#    'NewDeaths': 3,
#    'TotalDeaths': 927,
#    'NewRecovered': 96,
#    'TotalRecovered': 15458,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 953,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 7,
#    'TotalRecovered': 678,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 366,
#    'TotalConfirmed': 14238,
#    'NewDeaths': 3,
#    'TotalDeaths': 73,
#    'NewRecovered': 0,
#    'TotalRecovered': 8829,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 152,
#    'TotalConfirmed': 3457,
#    'NewDeaths': 4,
#    'TotalDeaths': 100,
#    'NewRecovered': 57,
#    'TotalRecovered': 1221,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 34,
#    'TotalConfirmed': 12085,
#    'NewDeaths': 0,
#    'TotalDeaths': 277,
#    'NewRecovered': 27,
#    'TotalRecovered': 10718,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 514,
#    'TotalConfirmed': 35466,
#    'NewDeaths': 4,
#    'TotalDeaths': 289,
#    'NewRecovered': 834,
#    'TotalRecovered': 25882,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 2207,
#    'NewDeaths': 1,
#    'TotalDeaths': 27,
#    'NewRecovered': 54,
#    'TotalRecovered': 1722,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 19,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1097,
#    'NewDeaths': 1,
#    'TotalDeaths': 28,
#    'NewRecovered': 27,
#    'TotalRecovered': 845,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 1442,
#    'NewDeaths': 1,
#    'TotalDeaths': 32,
#    'NewRecovered': 15,
#    'TotalRecovered': 868,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 446,
#    'NewDeaths': 0,
#    'TotalDeaths': 32,
#    'NewRecovered': 4,
#    'TotalRecovered': 214,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 418,
#    'NewDeaths': 2,
#    'TotalDeaths': 8,
#    'NewRecovered': 3,
#    'TotalRecovered': 62,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 82,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 55,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 1763,
#    'NewDeaths': 1,
#    'TotalDeaths': 75,
#    'NewRecovered': 16,
#    'TotalRecovered': 1416,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 4063,
#    'NewDeaths': 0,
#    'TotalDeaths': 110,
#    'NewRecovered': 4,
#    'TotalRecovered': 3922,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 194,
#    'TotalConfirmed': 3895,
#    'NewDeaths': 8,
#    'TotalDeaths': 179,
#    'NewRecovered': 11,
#    'TotalRecovered': 1705,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 1252,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 18,
#    'TotalRecovered': 362,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 529,
#    'NewDeaths': 1,
#    'TotalDeaths': 5,
#    'NewRecovered': 1,
#    'TotalRecovered': 66,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 43,
#    'TotalConfirmed': 8445,
#    'NewDeaths': 1,
#    'TotalDeaths': 120,
#    'NewRecovered': 143,
#    'TotalRecovered': 7311,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 2013,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 24,
#    'TotalRecovered': 1217,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 1776,
#    'NewDeaths': 3,
#    'TotalDeaths': 104,
#    'NewRecovered': 35,
#    'TotalRecovered': 1058,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 646,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 1,
#    'TotalRecovered': 601,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 110,
#    'TotalConfirmed': 1682,
#    'NewDeaths': 2,
#    'TotalDeaths': 83,
#    'NewRecovered': 33,
#    'TotalRecovered': 311,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 337,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 325,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 3494,
#    'TotalConfirmed': 142690,
#    'NewDeaths': 424,
#    'TotalDeaths': 16872,
#    'NewRecovered': 3202,
#    'TotalRecovered': 104078,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 366,
#    'TotalConfirmed': 11459,
#    'NewDeaths': 13,
#    'TotalDeaths': 398,
#    'NewRecovered': 192,
#    'TotalRecovered': 6421,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 99,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 0,
#    'TotalRecovered': 93,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 197,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 3,
#    'TotalRecovered': 98,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 324,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 315,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 82,
#    'TotalConfirmed': 8692,
#    'NewDeaths': 0,
#    'TotalDeaths': 212,
#    'NewRecovered': 78,
#    'TotalRecovered': 7696,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 44,
#    'TotalConfirmed': 553,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 6,
#    'TotalRecovered': 151,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 261,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 2,
#    'TotalRecovered': 167,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 32,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 17,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 273,
#    'TotalConfirmed': 5335,
#    'NewDeaths': 2,
#    'TotalDeaths': 18,
#    'NewRecovered': 36,
#    'TotalRecovered': 913,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 179,
#    'TotalConfirmed': 48847,
#    'NewDeaths': 4,
#    'TotalDeaths': 6076,
#    'NewRecovered': 0,
#    'TotalRecovered': 181,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1504,
#    'NewDeaths': 0,
#    'TotalDeaths': 22,
#    'NewRecovered': 0,
#    'TotalRecovered': 1482,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1464,
#    'NewDeaths': 0,
#    'TotalDeaths': 55,
#    'NewRecovered': 0,
#    'TotalRecovered': 953,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 980,
#    'NewDeaths': 1,
#    'TotalDeaths': 66,
#    'NewRecovered': 0,
#    'TotalRecovered': 881,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 501,
#    'TotalConfirmed': 15682,
#    'NewDeaths': 8,
#    'TotalDeaths': 407,
#    'NewRecovered': 210,
#    'TotalRecovered': 5101,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 8628,
#    'NewDeaths': 0,
#    'TotalDeaths': 242,
#    'NewRecovered': 0,
#    'TotalRecovered': 8138,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 1006,
#    'TotalConfirmed': 22077,
#    'NewDeaths': 3,
#    'TotalDeaths': 99,
#    'NewRecovered': 41,
#    'TotalRecovered': 7530,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 6472,
#    'TotalConfirmed': 132405,
#    'NewDeaths': 88,
#    'TotalDeaths': 2551,
#    'NewRecovered': 9809,
#    'TotalRecovered': 50056,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 489,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 1,
#    'TotalRecovered': 415,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 848,
#    'TotalConfirmed': 20059,
#    'NewDeaths': 8,
#    'TotalDeaths': 429,
#    'NewRecovered': 0,
#    'TotalRecovered': 13759,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 1261,
#    'NewDeaths': 0,
#    'TotalDeaths': 11,
#    'NewRecovered': 14,
#    'TotalRecovered': 647,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 5961,
#    'TotalConfirmed': 220749,
#    'NewDeaths': 220,
#    'TotalDeaths': 6308,
#    'NewRecovered': 4591,
#    'TotalRecovered': 111724,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 605,
#    'TotalConfirmed': 25392,
#    'NewDeaths': 22,
#    'TotalDeaths': 1074,
#    'NewRecovered': 252,
#    'TotalRecovered': 5706,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 440,
#    'TotalConfirmed': 29017,
#    'NewDeaths': 15,
#    'TotalDeaths': 1237,
#    'NewRecovered': 299,
#    'TotalRecovered': 14104,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 283,
#    'TotalConfirmed': 36463,
#    'NewDeaths': 7,
#    'TotalDeaths': 1512,
#    'NewRecovered': 238,
#    'TotalRecovered': 22438,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 1828,
#    'TotalConfirmed': 78416,
#    'NewDeaths': 0,
#    'TotalDeaths': 70,
#    'NewRecovered': 1956,
#    'TotalRecovered': 55252,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 111,
#    'TotalConfirmed': 1437,
#    'NewDeaths': 1,
#    'TotalDeaths': 32,
#    'NewRecovered': 7,
#    'TotalRecovered': 928,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 275,
#    'TotalConfirmed': 21679,
#    'NewDeaths': 14,
#    'TotalDeaths': 1394,
#    'NewRecovered': 190,
#    'TotalRecovered': 15635,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 8697,
#    'TotalConfirmed': 519458,
#    'NewDeaths': 114,
#    'TotalDeaths': 6819,
#    'NewRecovered': 5266,
#    'TotalRecovered': 274128,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 541,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 11,
#    'TotalRecovered': 332,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 15,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 18,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 25,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 694,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 520,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 659,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 20,
#    'TotalRecovered': 176,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 3366,
#    'TotalConfirmed': 123308,
#    'NewDeaths': 39,
#    'TotalDeaths': 932,
#    'NewRecovered': 1519,
#    'TotalRecovered': 82548,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 145,
#    'TotalConfirmed': 4996,
#    'NewDeaths': 4,
#    'TotalDeaths': 60,
#    'NewRecovered': 128,
#    'TotalRecovered': 3228,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 76,
#    'TotalConfirmed': 12251,
#    'NewDeaths': 1,
#    'TotalDeaths': 253,
#    'NewRecovered': 54,
#    'TotalRecovered': 11465,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 11,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 1132,
#    'NewDeaths': 0,
#    'TotalDeaths': 51,
#    'NewRecovered': 22,
#    'TotalRecovered': 670,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 347,
#    'TotalConfirmed': 40197,
#    'NewDeaths': 1,
#    'TotalDeaths': 26,
#    'NewRecovered': 768,
#    'TotalRecovered': 28808,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 1545,
#    'NewDeaths': 0,
#    'TotalDeaths': 28,
#    'NewRecovered': 1,
#    'TotalRecovered': 1410,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 1492,
#    'NewDeaths': 0,
#    'TotalDeaths': 109,
#    'NewRecovered': 0,
#    'TotalRecovered': 1359,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 66,
#    'TotalConfirmed': 2579,
#    'NewDeaths': 2,
#    'TotalDeaths': 87,
#    'NewRecovered': 27,
#    'TotalRecovered': 559,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 3809,
#    'TotalConfirmed': 65736,
#    'NewDeaths': 69,
#    'TotalDeaths': 1423,
#    'NewRecovered': 1844,
#    'TotalRecovered': 36850,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 23,
#    'TotalConfirmed': 1693,
#    'NewDeaths': 3,
#    'TotalDeaths': 27,
#    'NewRecovered': 1,
#    'TotalRecovered': 49,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 396,
#    'TotalConfirmed': 243605,
#    'NewDeaths': 0,
#    'TotalDeaths': 27136,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 1884,
#    'NewDeaths': 0,
#    'TotalDeaths': 11,
#    'NewRecovered': 56,
#    'TotalRecovered': 1252,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 128,
#    'TotalConfirmed': 7007,
#    'NewDeaths': 14,
#    'TotalDeaths': 447,
#    'NewRecovered': 140,
#    'TotalRecovered': 2556,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 196,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 9,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 486,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 1,
#    'TotalRecovered': 247,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 1247,
#    'TotalConfirmed': 50931,
#    'NewDeaths': 20,
#    'TotalDeaths': 4874,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 31094,
#    'NewDeaths': 0,
#    'TotalDeaths': 1938,
#    'NewRecovered': 0,
#    'TotalRecovered': 28800,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 170,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 3,
#    'TotalRecovered': 71,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 443,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 431,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 4971,
#    'NewDeaths': 1,
#    'TotalDeaths': 50,
#    'NewRecovered': 130,
#    'TotalRecovered': 3288,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 3134,
#    'NewDeaths': 0,
#    'TotalDeaths': 58,
#    'NewRecovered': 0,
#    'TotalRecovered': 2987,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 24,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 530,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 12,
#    'TotalRecovered': 291,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 117,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 109,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1094,
#    'NewDeaths': 0,
#    'TotalDeaths': 49,
#    'NewRecovered': 0,
#    'TotalRecovered': 995,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 1459,
#    'TotalConfirmed': 176677,
#    'NewDeaths': 14,
#    'TotalDeaths': 4792,
#    'NewRecovered': 985,
#    'TotalRecovered': 150087,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 694,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 58,
#    'TotalRecovered': 219,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 762,
#    'TotalConfirmed': 31177,
#    'NewDeaths': 10,
#    'TotalDeaths': 890,
#    'NewRecovered': 414,
#    'TotalRecovered': 14489,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 491,
#    'TotalConfirmed': 41990,
#    'NewDeaths': 1,
#    'TotalDeaths': 288,
#    'NewRecovered': 815,
#    'TotalRecovered': 26761,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 1426,
#    'TotalConfirmed': 295828,
#    'NewDeaths': 181,
#    'TotalDeaths': 41747,
#    'NewRecovered': 1,
#    'TotalRecovered': 1283,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 25540,
#    'TotalConfirmed': 2074526,
#    'NewDeaths': 767,
#    'TotalDeaths': 115436,
#    'NewRecovered': 9220,
#    'TotalRecovered': 556606,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 847,
#    'NewDeaths': 0,
#    'TotalDeaths': 23,
#    'NewRecovered': 4,
#    'TotalRecovered': 784,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 97,
#    'TotalConfirmed': 4966,
#    'NewDeaths': 0,
#    'TotalDeaths': 19,
#    'NewRecovered': 116,
#    'TotalRecovered': 3874,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 2904,
#    'NewDeaths': 1,
#    'TotalDeaths': 24,
#    'NewRecovered': 0,
#    'TotalRecovered': 487,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 334,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 323,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 2,
#    'TotalRecovered': 8,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 73,
#    'TotalConfirmed': 705,
#    'NewDeaths': 21,
#    'TotalDeaths': 160,
#    'NewRecovered': 11,
#    'TotalRecovered': 39,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 1357,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 1104,
#    'Date': '2020-06-14T10:09:21Z'},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 356,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 3,
#    'TotalRecovered': 54,
#    'Date': '2020-06-14T10:09:21Z'}],
#  'Date': '2020-06-14T10:09:21Z'}
